# %% [markdown]
# ## read dataset

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 5.0 MB/s eta 0:00:03
#    - -------------------------------------- 0.5/11.6 MB 6.2 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.6 MB 7.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.6 MB 7.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.6 MB 7.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.6 MB 8.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.6 MB 8.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.6 MB 8.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.8/11.6 MB 8.7 MB/s eta 0:00:01
#    -------------- ------------------------- 4.1/11.6 MB 8.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
data = pd.read_csv("GlobalLandTemperaturesByCity.csv")

# %%
data
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
data.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
data.tail()
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
# 8599211  Zwolle  Netherlands   52.24N     5.26E

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             object
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: float64(2), object(5)
# memory usage: 459.2+ MB

# %%
data.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        8.235082e+06                   8.235082e+06
# mean         1.672743e+01                   1.028575e+00
# std          1.035344e+01                   1.129733e+00
# min         -4.270400e+01                   3.400000e-02
# 25%          1.029900e+01                   3.370000e-01
# 50%          1.883100e+01                   5.910000e-01
# 75%          2.521000e+01                   1.349000e+00
# max          3.965100e+01                   1.539600e+01

# %%
data.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data["City"].value_counts()
# Out:
# City
# Springfield     9545
# Worcester       8359
# León            7469
# Rongcheng       6526
# Cambridge       6478
#                 ...
# Machala         1591
# Chimbote        1584
# Chiclayo        1584
# Trujillo        1584
# Port Moresby    1581
# Name: count, Length: 3448, dtype: int64

# %%
data["Country"].value_counts()
# Out:
# Country
# India               1014906
# China                827802
# United States        687289
# Brazil               475580
# Russia               461234
#                      ...
# Lesotho                1881
# Eritrea                1797
# Djibouti               1797
# Oman                   1653
# Papua New Guinea       1581
# Name: count, Length: 159, dtype: int64

# %%
data["dt"] = data["dt"].apply(lambda i:i.replace("-" , "")).astype(int)

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                          1.737   Århus
# 1        17431201                 NaN                            NaN   Århus
# 2        17440101                 NaN                            NaN   Århus
# 3        17440201                 NaN                            NaN   Århus
# 4        17440301                 NaN                            NaN   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                          0.236  Zwolle
# 8599208  20130601              15.043                          0.261  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
# 8599211  20130901                 NaN                            NaN  Zwolle
#
#              Country Latitude Longitude
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             int32
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: float64(2), int32(1), object(4)
# memory usage: 426.4+ MB

# %%
data["Latitude"] = data["Latitude"].apply(lambda i:i.replace("N" , ""))
data["Latitude"] = data["Latitude"].apply(lambda i:i.replace("S" , "")).astype(float)

# %%
data[data["Latitude"]=="34.56S"]
# Out:
# Empty DataFrame
# Columns: [dt, AverageTemperature, AverageTemperatureUncertainty, City, Country, Latitude, Longitude]
# Index: []

# %%
data[data["Country"]=="India"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 49880    18160301              19.934                          2.258
# 49881    18160401              26.641                          3.398
# 49882    18160501              32.535                          2.408
# 49883    18160601              33.254                          2.123
# 49884    18160701              31.105                          1.848
# ...           ...                 ...                            ...
# 8385505  20130501              29.286                          0.516
# 8385506  20130601              25.401                          0.400
# 8385507  20130701              24.232                          0.323
# 8385508  20130801              24.493                          0.366
# 8385509  20130901                 NaN                            NaN
#
#               City Country  Latitude Longitude
# 49880       Abohar   India     29.74    73.85E
# ...

# %%
india = data[data["Country"]=="India"]

# %%
c_india = india["City"].value_counts()

# %%
india[india["City"]=="Delhi"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 1938830  17960101              14.590                          2.374  Delhi
# 1938831  17960201              17.109                          1.940  Delhi
# 1938832  17960301              21.454                          2.608  Delhi
# 1938833  17960401              28.715                          2.122  Delhi
# 1938834  17960501              33.726                          1.997  Delhi
# ...           ...                 ...                            ...    ...
# 1941438  20130501              34.746                          0.501  Delhi
# 1941439  20130601              33.066                          0.669  Delhi
# 1941440  20130701              31.053                          0.490  Delhi
# 1941441  20130801              29.900                          0.604  Delhi
# 1941442  20130901                 NaN                            NaN  Delhi
#
#         Country  Latitude Longitude
# ...

# %%
india[india["City"]=="Mumbai"]
# Out:
# Empty DataFrame
# Columns: [dt, AverageTemperature, AverageTemperatureUncertainty, City, Country, Latitude, Longitude]
# Index: []

# %%
a = []
for i in india["City"].values:
  if i not in a:
    a.append(i)
print(a)
# Out:
# ['Abohar', 'Achalpur', 'Adilabad', 'Adoni', 'Agartala', 'Agra', 'Ahmadabad', 'Ahmadnagar', 'Aizawl', 'Ajmer', 'Akola', 'Alandur', 'Alappuzha', 'Aligarh', 'Allahabad', 'Alwar', 'Ambala', 'Ambarnath', 'Ambattur', 'Ambur', 'Amravati', 'Amritsar', 'Amroha', 'Anand', 'Anantapur', 'Ara', 'Asansol', 'Aurangabad', 'Avadi', 'Azamgarh', 'Badlapur', 'Bagaha', 'Bahadurgarh', 'Baharampur', 'Bahraich', 'Baidyabati', 'Baleshwar', 'Ballia', 'Bally', 'Balurghat', 'Banda', 'Bangalore', 'Bangaon', 'Bankura', 'Bansbaria', 'Barakpur', 'Baranagar', 'Barasat', 'Barddhaman', 'Bareli', 'Baripada', 'Barnala', 'Barsi', 'Basirhat', 'Basti', 'Batala', 'Beawar', 'Begusarai', 'Belgaum', 'Bellary', 'Bettiah', 'Bhadravati', 'Bhadreswar', 'Bhagalpur', 'Bharatpur', 'Bharuch', 'Bhatpara', 'Bhavnagar', 'Bhilai', 'Bhilwara', 'Bhimavaram', 'Bhind', 'Bhiwandi', 'Bhiwani', 'Bhopal', 'Bhubaneswar', 'Bhuj', 'Bhusawal', 'Bid', 'Bidar', 'Bihar', 'Bijapur', 'Bikaner', 'Bilaspur', 'Bokaro', 'Bombay', 'Botad', 'Brahmapur', 'Budaun
# ...

# %%
for i in a:
  if i[0].lower()=="b":
    print(i)
  elif i[0].lower()=="m":
    print(i)
# Out:
# Badlapur
# Bagaha
# Bahadurgarh
# Baharampur
# Bahraich
# Baidyabati
# Baleshwar
# Ballia
# Bally
# Balurghat
# Banda
# Bangalore
# Bangaon
# Bankura
# Bansbaria
# Barakpur
# Baranagar
# Barasat
# Barddhaman
# Bareli
# Baripada
# Barnala
# Barsi
# Basirhat
# Basti
# Batala
# Beawar
# Begusarai
# Belgaum
# Bellary
# Bettiah
# Bhadravati
# Bhadreswar
# Bhagalpur
# Bharatpur
# Bharuch
# Bhatpara
# Bhavnagar
# Bhilai
# Bhilwara
# Bhimavaram
# Bhind
# Bhiwandi
# Bhiwani
# Bhopal
# Bhubaneswar
# Bhuj
# Bhusawal
# Bid
# Bidar
# Bihar
# Bijapur
# Bikaner
# Bilaspur
# Bokaro
# Bombay
# Botad
# Brahmapur
# Budaun
# Bulandshahr
# Burhanpur
# Machilipatnam
# Madanapalle
# Madhyamgram
# Madras
# Madurai
# Mahbubnagar
# Mahesana
# Maisuru
# Malegaon
# Maler Kotla
# Mandsaur
# Mandya
# Mangaluru
# Mathura
# Mau
# Mirzapur
# Moga
# Moradabad
# Morena
# Mormugao
# Morvi
# Motihari
# Munger
# Murwara
# Muzaffarnagar
# Muzaffarpur

# %%
india[india["City"]=="Bombay"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 1039968  17960101              24.317                          2.190  Bombay
# 1039969  17960201              23.923                          1.484  Bombay
# 1039970  17960301              24.407                          2.309  Bombay
# 1039971  17960401              27.171                          1.650  Bombay
# 1039972  17960501              29.050                          1.290  Bombay
# ...           ...                 ...                            ...     ...
# 1042576  20130501              29.718                          0.574  Bombay
# 1042577  20130601              27.686                          0.260  Bombay
# 1042578  20130701              26.519                          0.177  Bombay
# 1042579  20130801              26.953                          0.390  Bombay
# 1042580  20130901                 NaN                            NaN  Bombay
#
#         Country  Latitude Longitude
# ...

# %% [markdown]
# ## Indias Cities

# %%
bombay = india[india["City"]=="Bombay"]["AverageTemperature"].mean()
delhi = india[india["City"]=="Delhi"]["AverageTemperature"].mean()
calcutta = india[india["City"]=="Calcutta"]["AverageTemperature"].mean()

# %%
bombay
# Out:
# 26.631452153110047

# %%
delhi
# Out:
# 25.16586090225564

# %%
calcutta
# Out:
# 26.04215205371248

# %%
china = data[data["Country"] == "China"]
china
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 11925    18200801              20.146                          2.286  Ürümqi
# 11926    18200901              15.331                          1.775  Ürümqi
# 11927    18201001               5.256                          1.848  Ürümqi
# 11928    18201101              -4.956                          2.190  Ürümqi
# 11929    18201201             -14.118                          2.581  Ürümqi
# ...           ...                 ...                            ...     ...
# 8589600  20130501              19.473                          0.227   Zunyi
# 8589601  20130601              23.670                          0.575   Zunyi
# 8589602  20130701              26.159                          0.713   Zunyi
# 8589603  20130801              25.502                          0.587   Zunyi
# 8589604  20130901                 NaN                            NaN   Zunyi
#
#         Country  Latitude Longitude
# ...

# %%
china["City"].value_counts()
# Out:
# City
# Rongcheng    6526
# Haikou       4456
# Yichun       4391
# Jining       4391
# Haicheng     4295
#              ...
# Macheng      2073
# Wuhu         2073
# Wuhan        2073
# Ezhou        2073
# Ruian        2073
# Name: count, Length: 371, dtype: int64

# %%
china[china["City"]=="Shanghai"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 6905101  18410101               1.809                          2.733
# 6905102  18410201               3.366                          1.917
# 6905103  18410301               7.122                          1.936
# 6905104  18410401              13.306                          2.004
# 6905105  18410501              19.007                          1.369
# ...           ...                 ...                            ...
# 6907169  20130501              21.292                          0.265
# 6907170  20130601              24.637                          1.031
# 6907171  20130701              30.623                          1.371
# 6907172  20130801              30.493                          0.603
# 6907173  20130901                 NaN                            NaN
#
#              City Country  Latitude Longitude
# 6905101  Shanghai   China     31.35   120.63E
# ...

# %%
b = []
for i in china["City"].values:
  if i in b:
    pass
  else:
    b.append(i)
b
# Out:
# ['Ürümqi',
#  'Acheng',
#  'Aksu',
#  'Altay',
#  'Anbu',
#  'Anda',
#  'Ankang',
#  'Anqing',
#  'Anqiu',
#  'Anshan',
#  'Anshun',
#  'Anyang',
#  'Badaojiang',
#  'Baicheng',
#  'Baiyin',
#  'Bantou',
#  'Baoding',
#  'Baoji',
#  'Baoshan',
#  'Beian',
#  'Beibei',
#  'Beihai',
#  'Beipiao',
#  'Bengbu',
#  'Benxi',
#  'Binzhou',
#  'Boshan',
#  'Bozhou',
#  'Buhe',
#  'Cangzhou',
#  'Changchun',
#  'Changde',
#  'Changji',
#  'Changzhou',
#  'Chaohu',
#  'Chaoyang',
#  'Chaozhou',
#  'Chengde',
#  'Chengdu',
#  'Chenghai',
#  'Chenzhou',
#  'Chifeng',
#  'Chizhou',
#  'Chongqing',
#  'Chuncheng',
#  'Chuzhou',
#  'Daan',
#  'Dali',
#  'Dalian',
#  'Daliang',
#  'Dandong',
#  'Danshui',
#  'Datong',
#  'Dawukou',
#  'Daxian',
#  'Dehui',
#  'Deyang',
#  'Dezhou',
#  'Didao',
#  'Dingzhou',
#  'Donghai',
#  'Dongli',
#  'Dongling',
#  'Dongtai',
#  'Dongying',
#  'Dunhua',
#  'Encheng',
#  'Ezhou',
#  'Fengcheng',
#  'Foshan',
#  'Fuling',
#  'Fushun',
#  'Fuxin',
#  'Fuyang',
# ...

# %%
for i in b:
  if i[0].lower()=="p":
    print(i)
# Out:
# Panzhihua
# Peking
# Pingdingshan
# Pingliang
# Pingshan
# Pingxiang
# Pulandian
# Puqi
# Puyang

# %%
shanghai = china[china["City"]=="Shanghai"]["AverageTemperature"].mean()
beijing = china[china["City"]=="Peking"]["AverageTemperature"].mean()
hong_kong = china[china["City"]=="Honggang"]["AverageTemperature"].mean()

# %%
beijing
# Out:
# 11.80938324652778

# %%
shanghai
# Out:
# 15.969511583011583

# %%
hong_kong
# Out:
# 3.625744065602072

# %%
usa = data[data["Country"]=="United States"]

# %%
usa
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 47555    18200101               2.101                          3.217  Abilene
# 47556    18200201               6.926                          2.853  Abilene
# 47557    18200301              10.767                          2.395  Abilene
# 47558    18200401              17.989                          2.202  Abilene
# 47559    18200501              21.809                          2.036  Abilene
# ...           ...                 ...                            ...      ...
# 8439242  20130501              15.544                          0.281  Yonkers
# 8439243  20130601              20.892                          0.273  Yonkers
# 8439244  20130701              24.722                          0.279  Yonkers
# 8439245  20130801              21.001                          0.323  Yonkers
# 8439246  20130901              17.408                          1.048  Yonkers
#
# ...

# %%
usa["City"].value_counts()
# Out:
# City
# Springfield    9545
# Columbus       6478
# Aurora         6101
# Arlington      5564
# Peoria         5384
#                ...
# Sacramento     1977
# Lancaster      1977
# Riverside      1977
# Burbank        1977
# Fairfield      1977
# Name: count, Length: 248, dtype: int64

# %%
La = usa[usa["City"]=="Los Angeles"]["AverageTemperature"].mean()
new_york = usa[usa["City"]=="New York"]["AverageTemperature"].mean()
washington = usa[usa["City"]=="Washington"]["AverageTemperature"].mean()

# %%
La
# Out:
# 15.878038442083966

# %%
new_york
# Out:
# 9.523295607566528

# %%
washington
# Out:
# 11.918474511061238

# %%
brazil = data[data["Country"]=="Brazil"]

# %%
brazil
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 152741   18320101              25.953                          1.570
# 152742   18320201              25.933                          2.372
# 152743   18320301              25.968                          1.585
# 152744   18320401              25.100                          2.175
# 152745   18320501              24.213                          1.809
# ...           ...                 ...                            ...
# 8109068  20130501              18.377                          0.527
# 8109069  20130601              18.072                          0.398
# 8109070  20130701              17.539                          0.646
# 8109071  20130801              18.595                          0.614
# 8109072  20130901                 NaN                            NaN
#
#                   City Country  Latitude Longitude
# 152741      Alagoinhas  Brazil     12.05    37.81W
# ...

# %%
brazil["City"].value_counts()
# Out:
# City
# Boa Vista                   2277
# Santarém                    2277
# Manaus                      2277
# Macapá                      2277
# Nossa Senhora Do Socorro    2181
#                             ...
# Mossoró                     1953
# Olinda                      1953
# Parnamirim                  1953
# Camaragibe                  1953
# Rio Branco                  1901
# Name: count, Length: 220, dtype: int64

# %%
d = []
for i in brazil["City"].values:
  if i not in d:
    d.append(i)

d
# Out:
# ['Alagoinhas',
#  'Americana',
#  'Anápolis',
#  'Ananindeua',
#  'Angra Dos Reis',
#  'Apucarana',
#  'Araçatuba',
#  'Aracaju',
#  'Araguaína',
#  'Arapiraca',
#  'Araraquara',
#  'Araras',
#  'Araruama',
#  'Araucária',
#  'Atibaia',
#  'Barbacena',
#  'Barra Mansa',
#  'Barreiras',
#  'Barretos',
#  'Barueri',
#  'Bauru',
#  'Belém',
#  'Belford Roxo',
#  'Belo Horizonte',
#  'Betim',
#  'Birigui',
#  'Blumenau',
#  'Boa Vista',
#  'Botucatu',
#  'Bragança Paulista',
#  'Brasília',
#  'Cabo Frio',
#  'Cachoeirinha',
#  'Cachoeiro De Itapemirim',
#  'Camaçari',
#  'Camaragibe',
#  'Campina Grande',
#  'Campinas',
#  'Campo Grande',
#  'Campos',
#  'Canoas',
#  'Carapicuíba',
#  'Cariacica',
#  'Caruaru',
#  'Cascavel',
#  'Castanhal',
#  'Catanduva',
#  'Caucaia',
#  'Caxias',
#  'Caxias Do Sul',
#  'Chapecó',
#  'Colatina',
#  'Colombo',
#  'Conselheiro Lafaiete',
#  'Contagem',
#  'Coronel Fabriciano',
#  'Cotia',
#  'Criciúma',
#  'Cubatão',
#  'Cuiabá',
#  'Curitiba',
# ...

# %%
rio_de_janeiro = brazil[brazil["City"]=="Rio De Janeiro"]["AverageTemperature"].mean()
sao_paulo = brazil[brazil["City"]=="São Paulo"]["AverageTemperature"].mean()
salvador = brazil[brazil["City"]=="Salvador"]["AverageTemperature"].mean()

# %%
rio_de_janeiro
# Out:
# 23.788915553435114

# %%
sao_paulo
# Out:
# 19.69936784351145

# %%
salvador
# Out:
# 24.656971374045803

# %%
russia = data[data["Country"]=="Russia"]

# %%
russia
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 30064    18200801              13.221                          2.706
# 30065    18200901               7.744                          1.756
# 30066    18201001              -1.771                          1.837
# 30067    18201101             -11.387                          2.218
# 30068    18201201             -19.725                          2.549
# ...           ...                 ...                            ...
# 8578952  20130501              10.688                          0.349
# 8578953  20130601              16.522                          0.398
# 8578954  20130701              17.782                          0.555
# 8578955  20130801              16.000                          0.412
# 8578956  20130901                 NaN                            NaN
#
#              City Country  Latitude Longitude
# 30064      Abakan  Russia     53.84    91.36E
# ...

# %%
s = []
for i in russia["City"].values:
  if i in s:
    pass
  else:
    s.append(i)
for i in s:
  if i[0].lower()=="s":
    print(i)
# Out:
# Saint Petersburg
# Salavat
# Samara
# Saransk
# Sarapul
# Saratov
# Sergiyev Posad
# Serpukhov
# Severodvinsk
# Seversk
# Shakhty
# Smolensk
# Sochi
# Solikamsk
# Staryy Oskol
# Stavropol
# Sterlitamak
# Surgut
# Syktyvkar
# Syzran

# %%
moscow = russia[russia["City"]=="Moscow"]["AverageTemperature"].mean()
saint = russia[russia["City"]=="Saint Petersburg"]["AverageTemperature"].mean()
kazan = russia[russia["City"]=="Kazan"]["AverageTemperature"].mean()

# %%
moscow
# Out:
# 3.999710675931775

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(["Bombay" , "Delhi" , "Calcutta"] , [bombay , delhi , calcutta] , color=["red" , "green" , "lightblue"])
plt.plot([bombay , delhi , calcutta] , color="orange")
plt.title("India's top cities AverageTemperature")
plt.show()

# %%
plt.scatter(india["AverageTemperatureUncertainty"] , india["AverageTemperature"] , color="g")
plt.plot([india["AverageTemperatureUncertainty"].min() , india["AverageTemperatureUncertainty"].max()] , [india["AverageTemperature"].mean() , india["AverageTemperature"].mean()])
plt.show()

# %%
plt.scatter(china['AverageTemperatureUncertainty'] , china["AverageTemperature"] , color="red")
plt.plot([china["AverageTemperatureUncertainty"].min() , china["AverageTemperatureUncertainty"].max()] , [china["AverageTemperature"].mean() , china['AverageTemperature'].mean()])
plt.show()

# %%
# ax = plt.axes()
# ax.set_facecolor("#0207a6")
plt.scatter(usa["AverageTemperatureUncertainty"] , usa["AverageTemperature"] , color="purple")
plt.plot([usa["AverageTemperatureUncertainty"].min() , usa["AverageTemperatureUncertainty"].max()] , [usa["AverageTemperature"].mean() , usa["AverageTemperature"].mean()] )
plt.title("USA")
plt.show()

# %%
usa["AverageTemperature"].mean()
# Out:
# 13.949334923600649

# %%
plt.scatter(brazil["AverageTemperatureUncertainty"] , brazil["AverageTemperature"] , color="yellow")
plt.plot([brazil["AverageTemperatureUncertainty"].min() , brazil['AverageTemperatureUncertainty'].max()] , [brazil["AverageTemperature"].mean() , brazil["AverageTemperature"].mean()])
plt.show()

# %%
brazil["AverageTemperature"].mean()
# Out:
# 21.90276297977393

# %%
plt.scatter(russia["AverageTemperatureUncertainty"] , russia["AverageTemperature"])
plt.plot([russia["AverageTemperatureUncertainty"].min() , russia["AverageTemperatureUncertainty"].max()] , [russia["AverageTemperature"].mean() , russia["AverageTemperature"].mean()] , color="r")
plt.show()

# %%
a = [india["AverageTemperatureUncertainty"].mean() , china["AverageTemperatureUncertainty"].mean() , usa["AverageTemperatureUncertainty"].mean() , brazil['AverageTemperatureUncertainty'].mean(),
     russia["AverageTemperatureUncertainty"].mean()]
plt.bar(["India" , "China" , "USA" , "Brazil" , "Russia"] , a , color=["g" , "r" , "purple" , "yellow" , "blue"])
plt.plot(a , color="orange")
plt.title("Top 5 Countries AverageTemperatureUncertainty")
plt.show()

# %%
b = [india["AverageTemperature"].mean() , china["AverageTemperature"].mean() , usa['AverageTemperature'].mean() , brazil["AverageTemperature"].mean() , russia["AverageTemperature"].mean()]
plt.bar(["India" , "China" , "USA" , "Brazil" , "Russia"] , b , color=["g" , "r" , "purple" , "yellow" , "blue"])
plt.plot(b , color="orange")
plt.show()

# %%
data["AverageTemperature"].mean()
# Out:
# 16.72743263625063

# %%
d = data[data["AverageTemperature"]>=16.72743263625063]
d
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 80       17500701              17.831                          1.220   Århus
# 81       17500801              16.848                          0.736   Århus
# 140      17550701              17.572                          2.255   Århus
# 152      17560701              18.103                          2.502   Århus
# 164      17570701              20.179                          7.554   Århus
# ...           ...                 ...                            ...     ...
# 8599186  20110801              16.975                          0.139  Zwolle
# 8599197  20120701              17.329                          0.287  Zwolle
# 8599198  20120801              18.588                          0.224  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
#
#              Country  Latitude Longitude
# ...

# %%
d["Country"].value_counts()
# Out:
# Country
# India            890194
# Brazil           412635
# China            354370
# United States    285956
# Indonesia        273295
#                   ...
# Georgia             609
# Estonia             599
# Mongolia             84
# Ireland              54
# Norway               16
# Name: count, Length: 158, dtype: int64

# %%
d["City"].value_counts()
# Out:
# City
# Jamalpur         4886
# Hyderabad        4778
# San Cristóbal    4284
# Manzanillo       4266
# Santiago         4252
#                  ...
# Concepcion          2
# Arvada              1
# Christchurch        1
# Murmansk            1
# Norilsk             1
# Name: count, Length: 3418, dtype: int64

# %%
data[data["City"]=="Jamalpur"]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3356513  17960101              17.668                          2.310
# 3356514  17960201              19.774                          1.751
# 3356515  17960301              22.697                          2.380
# 3356516  17960401              26.195                          1.949
# 3356517  17960501              27.572                          1.645
# ...           ...                 ...                            ...
# 3361734  20130501              31.456                          0.418
# 3361735  20130601              30.929                          0.545
# 3361736  20130701              30.190                          0.354
# 3361737  20130801              29.608                          0.265
# 3361738  20130901                 NaN                            NaN
#
#              City     Country  Latitude Longitude
# 3356513  Jamalpur  Bangladesh     24.92    90.44E
# ...

# %%
data1 = pd.read_csv("GlobalLandTemperaturesByCity.csv")
data1
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
# o = "hello good morning"
# print(type(o))
# print(o.upper())
# print(o.count("o"))
# print(o.split(" "))
# print(o.split(" ")[0])

# o = "2013-10-01"
# print(o.split("-"))
# print(o.split("-")[2])

# %%
data1["dt"] = data1["dt"].apply(lambda i:i.split("-")[0])
data1
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        1743               6.068                          1.737   Århus
# 1        1743                 NaN                            NaN   Århus
# 2        1744                 NaN                            NaN   Århus
# 3        1744                 NaN                            NaN   Århus
# 4        1744                 NaN                            NaN   Århus
# ...       ...                 ...                            ...     ...
# 8599207  2013              11.464                          0.236  Zwolle
# 8599208  2013              15.043                          0.261  Zwolle
# 8599209  2013              18.775                          0.193  Zwolle
# 8599210  2013              18.025                          0.298  Zwolle
# 8599211  2013                 NaN                            NaN  Zwolle
#
#              Country Latitude Longitude
# 0            Denmark   57.05N    10.33E
# ...

# %%
s = []
for i in range(1743 , 2014):
  if i == 1746 or i == 1747 or i == 1748 or i == 1749:
    continue
  d1 = data1[data1["dt"]==str(i)]["AverageTemperature"].mean()
  s.append(d1)
len(s)
# Out:
# 267

# %%
w = []
for i in range(1743 , 2014):
  if i == 1746 or i == 1747 or i == 1748 or i == 1749:
    continue
  w.append(i)
w
# Out:
# [1743,
#  1744,
#  1745,
#  1750,
#  1751,
#  1752,
#  1753,
#  1754,
#  1755,
#  1756,
#  1757,
#  1758,
#  1759,
#  1760,
#  1761,
#  1762,
#  1763,
#  1764,
#  1765,
#  1766,
#  1767,
#  1768,
#  1769,
#  1770,
#  1771,
#  1772,
#  1773,
#  1774,
#  1775,
#  1776,
#  1777,
#  1778,
#  1779,
#  1780,
#  1781,
#  1782,
#  1783,
#  1784,
#  1785,
#  1786,
#  1787,
#  1788,
#  1789,
#  1790,
#  1791,
#  1792,
#  1793,
#  1794,
#  1795,
#  1796,
#  1797,
#  1798,
#  1799,
#  1800,
#  1801,
#  1802,
#  1803,
#  1804,
#  1805,
#  1806,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1823,
#  1824,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1835,
#  1836,
#  1837,
#  1838,
#  1839,
#  1840,
#  1841,
#  1842,
#  1843,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1857,
# ...

# %%
plt.subplot(2 , 1 , 1)
plt.title("Global yearly AverageTemperature(1743 to 2013)")
plt.plot(w , s)

plt.subplot(2 , 1 , 2)
plt.scatter(w , s , color="g")
plt.show()

# %%
l = []
for i in range(1743 , 2014):
  if i == 1746 or i == 1747 or i == 1748 or i == 1749:
    continue
  l.append(data1[data1["dt"]==str(i)]["AverageTemperatureUncertainty"].mean())
l
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 5
#       3   if i == 1746 or i == 1747 or i == 1748 or i == 1749:
#       4     continue
# ----> 5   l.append(data1[data1["dt"]==str(i)]["AverageTemperatureUncertainty"].mean())
#       6 l
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
plt.subplot(2 , 1 , 1)
plt.title("Global yearly AverageTemperatureUncertainty(1743 to 2013)")
plt.plot(w , l)

plt.subplot(2 , 1 , 2)
plt.scatter(w , l , color="g")

plt.show()

# %%
data1["dt"] = data["dt"].astype(int)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             int32
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: float64(2), int32(1), object(4)
# memory usage: 426.4+ MB

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                          1.737   Århus
# 1        17431201                 NaN                            NaN   Århus
# 2        17440101                 NaN                            NaN   Århus
# 3        17440201                 NaN                            NaN   Århus
# 4        17440301                 NaN                            NaN   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                          0.236  Zwolle
# 8599208  20130601              15.043                          0.261  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
# 8599211  20130901                 NaN                            NaN  Zwolle
#
#              Country  Latitude Longitude
# ...

# %%
data["Longitude"] = data["Longitude"].apply(lambda i:i.replace("E" , ""))
data["Longitude"] = data["Longitude"].apply(lambda i:i.replace("W" , "")).astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             int32
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       float64
#  6   Longitude                      float64
# dtypes: float64(4), int32(1), object(2)
# memory usage: 426.4+ MB

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                          1.737   Århus
# 1        17431201                 NaN                            NaN   Århus
# 2        17440101                 NaN                            NaN   Århus
# 3        17440201                 NaN                            NaN   Århus
# 4        17440301                 NaN                            NaN   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                          0.236  Zwolle
# 8599208  20130601              15.043                          0.261  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
# 8599211  20130901                 NaN                            NaN  Zwolle
#
#              Country  Latitude  Longitude
# ...

# %%
data[data["AverageTemperature"]==data["AverageTemperature"].min()]
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 5308640  19790201             -42.704                          0.972  Norilsk
#
#         Country  Latitude  Longitude
# 5308640  Russia     69.92      88.83

# %%
negative = data[data["AverageTemperature"]<=0]

# %%
negative["Country"].value_counts().head()
# Out:
# Country
# Russia           180704
# China            122338
# United States     59489
# Germany           28721
# Poland            26849
# Name: count, dtype: int64

# %%
n_r = negative[negative["Country"]=="Russia"]
n_c = negative[negative["Country"]=="China"]
n_u = negative[negative["Country"]=="United States"]
n_g = negative[negative["Country"]=="Germany"]
n_p = negative[negative["Country"]=="Poland"]

# %%
ax = plt.axes()
ax.set_facecolor("lightblue")
plt.bar(["Poland" , "Germany" , "USA" , "China" , "Russia"] , [len(n_p) , len(n_g) , len(n_u) , len(n_c) , len(n_r)] , color=["red" , "yellow" , "purple" , "darkred" , "blue"])
plt.plot([len(n_p) , len(n_g) , len(n_u) , len(n_c) , len(n_r)] ,  "o" , linestyle="solid", color='orange' , linewidth=4)
plt.title("Number of extrime cold case's in top 5 countries")
plt.show()

# %%
import numpy as np
arr = np.array([len(n_p) , len(n_g) , len(n_u) , len(n_c) , len(n_r)])
e = [0.3 , 0.0 , 0.0 , 0.0 , 0.0]
plt.pie(arr , labels=["Poland" , "Germany" , "USA" , "China" , "Russia"] , shadow=True, explode=e , colors=["red" , "yellow" , "purple" , "darkred" , "blue"])
plt.legend(title="Each contry:")
plt.title("Number of extrime cold case's in top 5 countries")
plt.show()

# %%
positive = data[data["AverageTemperature"]>=30]
positive
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 25774    20070301              30.036                          0.742      Aba
# 25798    20090301              30.024                          0.331      Aba
# 25853    18200801              32.877                          1.752   Abadan
# 25865    18210801              33.892                          1.819   Abadan
# 26091    18400601              33.608                          1.718   Abadan
# ...           ...                 ...                            ...      ...
# 8576144  20130401              32.605                          0.568   Zinder
# 8576145  20130501              34.403                          0.844   Zinder
# 8576146  20130601              32.488                          0.300   Zinder
# 8592946  17610701              30.188                          4.393  Zuwarah
# 8595803  19990801              30.001                          0.607  Zuwarah
#
# ...

# %%
positive["Country"].value_counts()
# Out:
# Country
# India                   164227
# Pakistan                 37988
# Nigeria                   7604
# Iran                      7335
# United States             5600
# Sudan                     4707
# Mexico                    3496
# Saudi Arabia              3258
# Egypt                     2440
# Iraq                      2136
# Burma                     2028
# United Arab Emirates      2022
# Niger                     1615
# Cameroon                  1356
# Mali                      1190
# Bangladesh                 957
# Algeria                    939
# Thailand                   858
# China                      845
# Qatar                      819
# Bahrain                    768
# Vietnam                    711
# Djibouti                   682
# Sri Lanka                  678
# Libya                      640
# Somalia                    577
# Burkina Faso               509
# Benin                      489
# Chad                       474
# Mauritania                 422
# ...

# %%
p_i = positive[positive["Country"]=="India"]
p_p = positive[positive["Country"]=="Pakistan"]
p_n = positive[positive["Country"]=="Nigeria"]
p_ir =  positive[positive["Country"]=="Iran"]
p_u = positive[positive["Country"]=="United States"]

# %%
ax = plt.axes()
ax.set_facecolor("lightyellow")
plt.bar(["India" , "Pakistan" , "Nigeria" ,"Iran" ,"USA"] , [len(p_i) , len(p_p) , len(p_n) , len(p_ir) , len(p_u)] , color=["yellow" ,"green" , "darkgreen" , "red" , "purple"])
plt.plot([len(p_i) , len(p_p) , len(p_n) , len(p_ir) , len(p_u)] , marker="o" , markersize=10 , linestyle="solid" , linewidth=5 , color="orange")
plt.title("Number of extrime hot case's in top 5 countries")
plt.show()

# %%
ar = np.array( [len(p_i) , len(p_p) , len(p_n) , len(p_ir) , len(p_u)])
plt.pie(ar , colors=["yellow" ,"green" , "darkgreen" , "red" , "purple"] , autopct="%1.1f%%" , labels=["India" , "Pakistan" , "Nigeria" ,"Iran" ,"USA"] , explode=[0.0 , 0.0 , 0.0 , 0.0 , 0.3])
plt.title("Number of extrime hot case's in top 5 countries")
plt.legend(title="each country")
plt.show()

# %%
positive
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 25774    20070301              30.036                          0.742      Aba
# 25798    20090301              30.024                          0.331      Aba
# 25853    18200801              32.877                          1.752   Abadan
# 25865    18210801              33.892                          1.819   Abadan
# 26091    18400601              33.608                          1.718   Abadan
# ...           ...                 ...                            ...      ...
# 8576144  20130401              32.605                          0.568   Zinder
# 8576145  20130501              34.403                          0.844   Zinder
# 8576146  20130601              32.488                          0.300   Zinder
# 8592946  17610701              30.188                          4.393  Zuwarah
# 8595803  19990801              30.001                          0.607  Zuwarah
#
# ...

# %%
miss = data.isnull()
for i in miss.columns:
  print(f"{i} : {len(miss[miss[i]==True])}")
# Out:
# dt : 0
# AverageTemperature : 364130
# AverageTemperatureUncertainty : 364130
# City : 0
# Country : 0
# Latitude : 0
# Longitude : 0

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                          1.737   Århus
# 1        17431201                 NaN                            NaN   Århus
# 2        17440101                 NaN                            NaN   Århus
# 3        17440201                 NaN                            NaN   Århus
# 4        17440301                 NaN                            NaN   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                          0.236  Zwolle
# 8599208  20130601              15.043                          0.261  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
# 8599211  20130901                 NaN                            NaN  Zwolle
#
#              Country  Latitude  Longitude
# ...

# %%
null_cells = data.isnull()

# Create a DataFrame with True/False only for null values
only_null_cells = null_cells.where(null_cells , data)
# Out:
# C:\Users\kianp\AppData\Local\Temp\ipykernel_23624\194887649.py:4: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   only_null_cells = null_cells.where(null_cells , data)

# %%
only_null_cells[only_null_cells["AverageTemperature"]==True]["City"].value_counts()
# Out:
# City
# Saint Denis     1039
# Port Louis      1039
# Fianarantsoa    1036
# Antananarivo     958
# Antsirabe        958
#                 ...
# Santa Fe           1
# Hachinohe          1
# Sanda              1
# Sanbu              1
# Linchuan           1
# Name: count, Length: 3323, dtype: int64

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    -------------------------- ------------- 163.8/250.0 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 5.2 MB/s eta 0:00:00
# ...

# %%
ex = only_null_cells[only_null_cells["AverageTemperature"]==True]["City"].value_counts()
ex.to_excel("missingvalues_city.xlsx")

# %%
ex_c = only_null_cells[only_null_cells["AverageTemperature"]==True]["Country"].value_counts()
ex_c.to_excel("miss_country.xlsx")

# %%
miss_country = pd.read_excel("miss_country.xlsx")
miss_country
# Out:
#               Country  count
# 0               India  54358
# 1           Indonesia  49960
# 2       United States  25775
# 3              Brazil  23935
# 4            Pakistan  15966
# ..                ...    ...
# 152          Mongolia      2
# 153  Papua New Guinea      1
# 154              Oman      1
# 155       South Korea      1
# 156            Jordan      1
#
# [157 rows x 2 columns]

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                          1.737   Århus
# 1        17431201                 NaN                            NaN   Århus
# 2        17440101                 NaN                            NaN   Århus
# 3        17440201                 NaN                            NaN   Århus
# 4        17440301                 NaN                            NaN   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                          0.236  Zwolle
# 8599208  20130601              15.043                          0.261  Zwolle
# 8599209  20130701              18.775                          0.193  Zwolle
# 8599210  20130801              18.025                          0.298  Zwolle
# 8599211  20130901                 NaN                            NaN  Zwolle
#
#              Country  Latitude  Longitude
# ...

# %%
data = data.interpolate(method="linear")
data
# Out:
# C:\Users\kianp\AppData\Local\Temp\ipykernel_23624\2812424474.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data = data.interpolate(method="linear")
#                dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        17431101               6.068                         1.7370   Århus
# 1        17431201               6.012                         2.1144   Århus
# 2        17440101               5.956                         2.4918   Århus
# 3        17440201               5.900                         2.8692   Århus
# 4        17440301               5.844                         3.2466   Århus
# ...           ...                 ...                            ...     ...
# 8599207  20130501              11.464                         0.2360  Zwolle
# 8599208  20130601              15.043                         0.2610  Zwolle
# ...

# %%
uuu = []
isnu = data.isnull()
for i in isnu.columns:
    www = isnu[isnu[i]==False]
    uuu.append(len(www))
uuu
# Out:
# [8599212, 8599212, 8599212, 8599212, 8599212, 8599212, 8599212]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['City'] = le.fit_transform(data['City'])
data['Country'] = le.fit_transform(data['Country'])

# %%
data
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  City  \
# 0        17431101               6.068                         1.7370  3443
# 1        17431201               6.012                         2.1144  3443
# 2        17440101               5.956                         2.4918  3443
# 3        17440201               5.900                         2.8692  3443
# 4        17440301               5.844                         3.2466  3443
# ...           ...                 ...                            ...   ...
# 8599207  20130501              11.464                         0.2360  3442
# 8599208  20130601              15.043                         0.2610  3442
# 8599209  20130701              18.775                         0.1930  3442
# 8599210  20130801              18.025                         0.2980  3442
# 8599211  20130901              18.025                         0.2980  3442
#
#          Country  Latitude  Longitude
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = data[["dt" , "AverageTemperatureUncertainty" , "City" , "Country" , "Latitude" , "Longitude"]]
Y = data["AverageTemperature"]

# %%
X_train , X_test , y_train , y_test = train_test_split(X , Y , test_size=0.2 , train_size=0.8 , random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()
LR.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = LR.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 55.992702810646655
# R^2 Score: 0.47397144617355413

# %%
dff = pd.read_csv("GlobalLandTemperaturesByCity.csv")
dff
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1743-11-01               6.068                          1.737
# 1        1743-12-01                 NaN                            NaN
# 2        1744-01-01                 NaN                            NaN
# 3        1744-02-01                 NaN                            NaN
# 4        1744-03-01                 NaN                            NaN
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 0         Århus      Denmark   57.05N    10.33E
# ...

# %%
dff['dt'] = pd.to_datetime(dff['dt']).apply(lambda x: x.toordinal())
dff
# Out:
#              dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0        719163               6.068                          1.737   Århus
# 1        719163                 NaN                            NaN   Århus
# 2        719163                 NaN                            NaN   Århus
# 3        719163                 NaN                            NaN   Århus
# 4        719163                 NaN                            NaN   Århus
# ...         ...                 ...                            ...     ...
# 8599207  719163              11.464                          0.236  Zwolle
# 8599208  719163              15.043                          0.261  Zwolle
# 8599209  719163              18.775                          0.193  Zwolle
# 8599210  719163              18.025                          0.298  Zwolle
# 8599211  719163                 NaN                            NaN  Zwolle
#
#              Country Latitude Longitude
# ...

# %%
X['dt'] = pd.to_datetime(dff['dt']).apply(lambda x: x.toordinal())
X
# Out:
# C:\Users\kianp\AppData\Local\Temp\ipykernel_23624\3407650254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['dt'] = pd.to_datetime(dff['dt']).apply(lambda x: x.toordinal())
#              dt  AverageTemperatureUncertainty  City  Country  Latitude  \
# 0        719163                         1.7370  3443       39     57.05
# 1        719163                         2.1144  3443       39     57.05
# 2        719163                         2.4918  3443       39     57.05
# 3        719163                         2.8692  3443       39     57.05
# 4        719163                         3.2466  3443       39     57.05
# ...         ...                            ...   ...      ...       ...
# ...

# %%
X_train , X_test , y_train , y_test = train_test_split(X , Y , test_size=0.3 , train_size=0.7 , random_state=42)

# %%
LR.fit(X_train , y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 LR.fit(X_train , y_test)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_base.py:578, in LinearRegression.fit(self, X, y, sample_weight)
#     574 n_jobs_ = self.n_jobs
#     576 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 578 X, y = self._validate_data(
# ...

# %%
X[X["Country"]==6019448]
# Out:
# Empty DataFrame
# Columns: [dt, AverageTemperatureUncertainty, City, Country, Latitude, Longitude]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
# Assuming data is your DataFrame and 'City' and 'Country' are the columns you want to transform
le = LabelEncoder()
data['City'] = le.fit_transform(data['City'])
data['Country'] = le.fit_transform(data['Country'])

# %%
from sklearn.model_selection import train_test_split
X = data.drop("AverageTemperature" , axis=1)
y = data["AverageTemperature"]
X_train , X_test , y_train , y_test = train_test_split(X , y , train_size=0.8 , random_state=0)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error' , metrics = ["accuracy"])
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 20, batch_size = 32)
